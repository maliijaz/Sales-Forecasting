# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %%
data = pd.read_csv('C:/Users/Ali/Desktop/train_sales_forecast.csv')

# %%
data.set_index('Date', inplace=True)

# %%
data["Weekly_Sales"].plot(kind='line', color='purple', figsize=(50,5))
# Out:
# <Axes: xlabel='Date'>

# %%
data.loc[data['Weekly_Sales'].idxmax(), 'Date']
# Out:
# '26-11-2010'

# %%
data[data['Date'] == '26-11-2010']
# Out:
#        Store  Dept        Date  Weekly_Sales  IsHoliday
# 42         1     1  26-11-2010      18905.30       True
# 159        1     2  26-11-2010      45888.31       True
# 276        1     3  26-11-2010      10755.17       True
# 393        1     4  26-11-2010      46409.95       True
# 510        1     5  26-11-2010      70475.75       True
# ...      ...   ...         ...           ...        ...
# 83492     10    94  26-11-2010      38847.52       True
# 83609     10    95  26-11-2010      62659.13       True
# 83726     10    96  26-11-2010      26139.60       True
# 83843     10    97  26-11-2010      15095.55       True
# 83960     10    98  26-11-2010      13214.37       True
#
# [716 rows x 5 columns]

# %%
data["Date"] = pd.to_datetime(data["Date"], format='%d-%m-%Y')

# %%
data.set_index('Date', inplace=True)

# %%
df_1_1 = data[data['Dept'] == 1 & (data['Store'] == 1)]

# %%
df_1_1['Weekly_Sales'].plot(kind='line', color='purple', figsize=(15,5), )
# Out:
# <Axes: xlabel='Date'>

# %%
df_1_2 = data[(data['Store'] == 1) & (data['Dept'] == 2)]

# %%
df_1_2['Weekly_Sales'].plot(kind='line', color='purple', figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df_2_1 = data[(data['Store'] == 2) & (data['Dept'] == 1)]

# %%
df_2_1['Weekly_Sales'].plot(kind='line', color='purple', figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df_2_2 = data[(data['Store'] == 2) & (data['Dept'] == 2)]

# %%
df_2_2['Weekly_Sales'].plot(kind='line', color='purple', figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df_3_1 = data[(data['Store'] == 3) & (data['Dept'] == 1)]

# %%
df_3_1['Weekly_Sales'].plot(kind='line', color='purple', figsize=(15,5))
# Out:
# <Axes: xlabel='Date'>
